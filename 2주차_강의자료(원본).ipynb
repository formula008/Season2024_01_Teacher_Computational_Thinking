# %% [markdown]
# <a href="https://colab.research.google.com/github/formula008/Season2024_01_Teacher_Computational_Thinking/blob/main/2%EC%A3%BC%EC%B0%A8_%EA%B0%95%EC%9D%98%EC%9E%90%EB%A3%8C(%EC%9B%90%EB%B3%B8).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 2.1  파이썬 명령어의 형식

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 2.2  실행 결과를 보여주는 출력 명령어
# ### 2.2.1  출력이란

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 2.2.2  출력 명령어 print()

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
print(123)
# Out:
# 123

# %%
print(2020)
# Out:
# 2020

# %%
print(가나다)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-a9a49ff8dd7c> in <module>()
# ----> 1 print(가나다)
#
# NameError: name '가나다' is not defined

# %%
print('가나다')
# Out:
# 가나다

# %%
print('123')
# Out:
# 123

# %%
print(123 + 2)
print('123' + 2)
# Out:
# 125
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-0c931b262974> in <cell line: 2>()
#       1 print(123 + 2)
# ----> 2 print('123' + 2)
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# ### 2.2.3  사칙연산 출력하기

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
print(123 + 9)
print(123 - 9)
# Out:
# 132
# 114

# %%
print('123 + 9')
print('123 - 9')
# Out:
# 123 + 9
# 123 - 9

# %%
print(108 * 8)
print(108 / 8)
# Out:
# 864
# 13.5

# %% [markdown]
# ### 2.2.4  기타 연산차 출력하기

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
print(108 // 8)
# Out:
# 13

# %%
print(108 % 8)
# Out:
# 4

# %%
print(108 ** 8)
# Out:
# 18509302102818816

# %%
print(5 ** 2)
# Out:
# 25

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
print(14 + 31)
# Out:
# 45

# %%
print('파이썬' + '프로그래밍')
# Out:
# 파이썬프로그래밍

# %%
print('파이썬', '프로그래밍')
print(14, 31)
# Out:
# 파이썬 프로그래밍
# 14 31

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
print('파이썬' + 3)
print('파이썬' - 3)
print('파이썬' / 3)
print('파이썬' * 3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-cdae05ce4922> in <module>()
# ----> 1 print('파이썬' + 3)
#       2 print('파이썬' - 3)
#       3 print('파이썬' / 3)
#       4 print('파이썬' * 3)
#
# TypeError: can only concatenate str (not "int") to str

# %%
print('파이썬+프로그래밍')
print('파이썬 + 프로그래밍')
# Out:
# 파이썬+프로그래밍
# 파이썬 + 프로그래밍

# %%
print(파이썬+프로그래밍)
print(파이썬 + 프로그래밍)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-cc7dd08aae40> in <module>()
# ----> 1 print(파이썬+프로그래밍)
#       2 print(파이썬 + 프로그래밍)
#
# NameError: name '파이썬' is not defined

# %%
# 1분 퀴즈
print('안녕하세요. 무엇이든 시켜보세요.')
# Out:
# 안녕하세요. 무엇이든 시켜보세요.

# %% [markdown]
# ## 2.3  데이터를 넣는 입력 명령어
# ### 2.3.1  입력이란
#
#
# *  사람이 직접 컴퓨터에 정보(데이터)를 넣어 주는것

# %% [markdown]
# ### 2.3.2  입력 명령어 input()

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
input()
# Out:
# 파이썬
# '파이썬'

# %%
input(3)
# Out:
# 3456
# '456'

# %%
input('입력 ')
# Out:
# 입력 7월 5일
# '7월 5일'

# %%
input('아이디: ')
input('비밀번호: ')
# Out:
# 아이디: gilbut
# 비밀번호: fighting!!
# 'fighting!!'

# %%
input('학번을 입력하세요 --> ')
# Out:
# 학번을 입력하세요 --> 20513
# '20513'

# %%
# 1번
print('무궁화 꽃이 피었습니다!'* 3)
# Out:
# 무궁화 꽃이 피었습니다!무궁화 꽃이 피었습니다!무궁화 꽃이 피었습니다!

# %%
# 2번
# print('95' + 3)    # 오류
print('95' * 3)
# Out:
# 959595

# %%
# 3번
print(input('닉네임을 입력해 주세요 --> ') + '님 안녕하세요')
# Out:
# 닉네임을 입력해 주세요 --> 졔졔쌤
# 졔졔쌤님 안녕하세요
